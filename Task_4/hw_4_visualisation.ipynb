# %% [markdown]
# # Домашная работа 3. Визуальный анализ.
#
# 1. Скачайте этот ноутбук к себе.
# 2. Заполните пропущенные ячейки, отвечая на заданные вопросы. Там должен быть код! (если не сказано обратное)
# 3. Сохраните результат в своём гитхаб репозитории.
#
# #### Полезная литература
#
# - [Галерея графиков Matplotlib](https://matplotlib.org/gallery/index.html)
# - [Галерея графиков Seaborn](http://seaborn.pydata.org/examples/index.html)
# - [Открытый курс машинного обучения. Тема 2: Визуализация данных c Python](https://habr.com/company/ods/blog/323210/)

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Визуальный анализ данных
#
# В этом задании вам предлагается провести визуальный анализ датасета о прокатах велосипедов https://www.kaggle.com/c/bike-sharing-demand/data. Оригинальная задача предполагает построение модели предсказания количества прокатов в городе в зависимости от погоды.

# %% [markdown]
# Для каждого дня проката известны следующие признаки (как они были указаны в источнике данных):
# - season: 1 - весна, 2 - лето, 3 - осень, 4 - зима
# - yr: 0 - 2011, 1 - 2012
# - mnth: от 1 до 12
# - holiday: 0 - нет праздника, 1 - есть праздник
# - weekday: от 0 до 6
# - workingday: 0 - нерабочий день, 1 - рабочий день
# - weathersit: оценка благоприятности погоды от 1 (чистый, ясный день) до 4 (ливень, туман)
# - temp: температура в Цельсиях
# - atemp: температура по ощущениям в Цельсиях
# - hum: влажность
# - windspeed(mph): скорость ветра в милях в час
# - windspeed(ms): скорость ветра в метрах в секунду
# - cnt: количество арендованных велосипедов (это целевой признак, его мы будем предсказывать)

# %% [markdown]
# Загрузите с помощью pandas файл `bikes_rent.csv.gz` и выведите первые 5 строк. Ознакомьтесь с данными с помощью функций describe и info.

# %%
df = pd.read_csv('bikes_rent.csv')

df.head()
print(len(df))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-6a4fb6ca6432> in <cell line: 1>()
# ----> 1 df = pd.read_csv('bikes_rent.csv')
#       2
#       3 df.head()
#       4 print(len(df))
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bikes_rent.csv'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   season          731 non-null    int64
#  1   yr              731 non-null    int64
#  2   mnth            731 non-null    int64
#  3   holiday         731 non-null    int64
#  4   weekday         731 non-null    int64
#  5   workingday      731 non-null    int64
#  6   weathersit      731 non-null    int64
#  7   temp            731 non-null    float64
#  8   atemp           731 non-null    float64
#  9   hum             731 non-null    float64
#  10  windspeed(mph)  731 non-null    float64
#  11  windspeed(ms)   731 non-null    float64
#  12  cnt             731 non-null    int64
# dtypes: float64(5), int64(8)
# memory usage: 74.4 KB

# %% [markdown]
# Давайте посмотрим на графиках, как целевой признак зависит количество прокатов (cnt) зависит от остальных признаков `df.columns[:-1]`.

# %%
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(16, 12))
for idx, feature in enumerate(df.columns[:-1]):
     df.plot(feature, "cnt", subplots=True, kind="scatter", ax=axes[idx // 4, idx % 4])

# %% [markdown]
# ## 1. Ответьте на вопросы:
#
# #### Каков характер зависимости числа прокатов от месяца?
#
# ответ: Число прокатов растет летом и падаем в остальное время
#
# #### Укажите один или два признака, от которых число прокатов скорее всего зависит линейно
# _(чем больше значение, тем больше прокатов или наоборот, например)_
#
# Можете проверить результат с помощью lnplot.
#
# ответ: Чем больше температура по ощущениям, тем больше кол-во прокатов.
# Чем больше температура, тем больше число прокатов

# %% [markdown]
# ## 2. Корреляционная матрица
#
# Напомним, что корреляция отражает взаимосвязь двух случайных величин. Она бывает положительная и отрицательная. Чем ближе коэффициент корреляции к нулю, тем меньше взаимосвязь. Чем больше абсолютная корреляци, тем взаимосвязь больше.
#
# Постройте heatmap корреляционной матрицы. Матрица формируется средствами pandas, со стандартным значением параметров.
#
# **Ответьте на вопрос**: с какими признаками количество прокатов коррелирует меньше всего (около 4 штуки). А с какими больше всего?

# %% [markdown]
# Ответ

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix)
# Out:
# <Axes: >

# %% [markdown]
# cnt меньше всего кореллирует со оценкой благоприятности погоды, влажность, выходными днями, рабочими днями

# %% [markdown]
# ## 3. Barpot
#
# Постройте Bar-график суммарного количества прокатов велосипедов по месяцам за каждый год одновременно. (будет 24 столбика)
#
# **Ответьте на вопрос:** почему в предыдущем графике была такая большая корреляция между количеством прокатов и годом?

# %% [markdown]
# Ответ:

# %%
df['month-year'] = pd.to_datetime(df['yr'].map(f)  + '-' + df['mnth'].astype(str) + '-' + '01').dt.strftime('%Y-%m')
df
# Out:
#      season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0         1   0     1        0        6           0           2  14.110847
# 1         1   0     1        0        0           0           2  14.902598
# 2         1   0     1        0        1           1           1   8.050924
# 3         1   0     1        0        2           1           1   8.200000
# 4         1   0     1        0        3           1           1   9.305237
# ..      ...  ..   ...      ...      ...         ...         ...        ...
# 726       1   1    12        0        4           1           2  10.420847
# 727       1   1    12        0        5           1           2  10.386653
# 728       1   1    12        0        6           0           2  10.386653
# 729       1   1    12        0        0           0           1  10.489153
# 730       1   1    12        0        1           1           2   8.849153
#
#         atemp      hum  windspeed(mph)  windspeed(ms)   cnt month-year
# 0    18.18125  80.5833       10.749882       4.805490   985    2010-01
# 1    17.68695  69.6087       16.652113       7.443949   801    2010-01
# 2     9.47025  43.7273       16.636703       7.437060  1349    2010-01
# 3    10.60610  59.0435       10.739832       4.800998  1562    2010-01
# 4    11.46350  43.6957       12.522300       5.597810  1600    2010-01
# ..        ...      ...             ...            ...   ...        ...
# 726  11.33210  65.2917       23.458911      10.486773  2114    2011-12
# 727  12.75230  59.0000       10.416557       4.656485  3095    2011-12
# 728  12.12000  75.2917        8.333661       3.725374  1341    2011-12
# 729  11.58500  48.3333       23.500518      10.505372  1796    2011-12
# 730  11.17435  57.7500       10.374682       4.637766  2729    2011-12
#
# [731 rows x 14 columns]

# %%
sns.barplot(x='month-year', y = 'cnt', data=df.groupby('month-year')[['cnt']].sum().reset_index())
# Out:
# <Axes: xlabel='month-year', ylabel='cnt'>

# %% [markdown]
# Большая корреляция между cnt и город  наблюдается, потому что в среднем в 2011 год за каждый месяц

# %% [markdown]
# ## 4. Countplot
#
# Постройте countplot диаграммы для признаков `weekday`, `weathersit`,
#
# **Ответьте на вопрос:** что вы можете сказать о том, как формировался этот датасет.
#
# **Ответьте на вопрос:** как называется распределение значений признака `weekday`?

# %% [markdown]
# Ответ: Каждая строчка датасета  - один день. На протяжении 2х лет. При этом Большинство дней было солнечными
#
# Ответ:Равномерное

# %%
sns.countplot(x = 'weekday', data = df)
# Out:
# <Axes: xlabel='weekday', ylabel='count'>

# %%
sns.countplot(x = 'weathersit', data = df)
# Out:
# <Axes: xlabel='weathersit', ylabel='count'>

# %% [markdown]
# ## 5. Распределение
#
# Постройте распределение целевого признака.
#
# **Ответьте на вопрос:** основываясь на графике, сколько приблизительно в среднем прокатов бывает в день?
#
# **Ответьте на вопрос:** Как называется полученное распределение?.

# %% [markdown]
# Ответ: 4000
#
# Ответ: Нормальное

# %%
sns.displot(df.cnt)

# %% [markdown]
# ## 6. Совместное распределение признаков
#
# Постройте график совместного распределения признаков температура и ощущение температуры.
#
# **Ответьте на вопрос:** вас в этом графике ничего не настораживает? Почему?

# %% [markdown]
# Ответ: ощущаемая и реальная темпераура должны примерно совпадать с небольшим отличием. Смущает температура 30 ощущаемая как 12

# %%
sns.jointplot(data=df, x = df.temp, y = df.atemp)

# %% [markdown]
# ## 7. Ящик с усами
#
# Нарисуйте сами для распределения количества прокатов велосипедов по месяцам в зависимости от того рабочий это день или нет.
#
# **Ответьте на вопрос:** почему в некоторых месяцах чаще берут велосипеды в будний день, а в некоторые - в выходной.

# %% [markdown]
# Ответ: В зимний месяц чаще берут в будни. Возможно доставщики или почтальоны
# Летом чаще берут в в выходные, когда люди выбираются на прогулку

# %%
sns.set(rc={'figure.figsize':(16,11)})
sns.boxplot(y = "mnth", x = "cnt", data = df, hue= 'workingday', orient = 'h')
# Out:
# <Axes: xlabel='cnt', ylabel='mnth'>

# %% [markdown]
# ## 8. Хитрый вопрос
#
# Правда ли, что при более сильном ветре человеку ощущается, что на улице холодне, чем на самом деле? Нарисуйте график, подтверждающий или опровергающий эту гипотезу. Обоснуйте. Возможно, вам придется создать новый признак.

# %% [markdown]
# Рассуждение:

# %%
sns.set(rc={'figure.figsize':(30,9)})
df['deltatemp'] = df['temp'] - df['atemp']
df1 = df[df['deltatemp'] < 15]
sns.jointplot(data=df, x = df1.deltatemp, y = df1['windspeed(ms)'])

# %% [markdown]
# Утверждение неверно.
